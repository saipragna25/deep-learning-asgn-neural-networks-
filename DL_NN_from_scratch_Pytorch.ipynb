# %% [markdown]
# <a href="https://colab.research.google.com/github/saipragna25/deep-learning-asgn-neural-networks-/blob/main/DL_NN_from_scratch_Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# preparing data

# %%
# 3 Dimension non-linear input data

n = 200
d = 3
x = torch.rand(n,d)
weights_true = torch.tensor([[2, 1,-1],[3,0,-1]]).T
bias_true = torch.tensor([[0.5],[0.1]])

y_true = torch.matmul((x ** 2).float() , weights_true.float()) + torch.matmul(x.float() , weights_true.float()) + bias_true.T.float()
print(f'x: {x.shape}, weights: {weights_true.shape}, bias: {bias_true.shape}, y: {y_true.shape}')
# Out:
# x: torch.Size([200, 3]), weights: torch.Size([3, 2]), bias: torch.Size([2, 1]), y: torch.Size([200, 2])

# %% [markdown]
# plotting the data

# %%
from sklearn.manifold import TSNE
view = TSNE(n_components=2, n_jobs=5).fit_transform(x)
view.shape
# Out:
# (200, 2)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
#y_pred = y_pred.astype('int')
fig = plt.figure(figsize=(10,5))
tsne = fig.add_subplot(111, projection='3d')
tsne.scatter(*zip(*view))
plt.show()

# %% [markdown]
# creating the model

# %%
import math
import torch.nn as nn

class MSE:
  def __call__(self, y_pred, y_true):
    self.y_pred = y_pred
    self.y_true = y_true
    return ((y_pred - y_true) ** 2).mean()

  def backward(self):
    n = self.y_true.shape[0]
    self.gradient = 2. * (self.y_pred - self.y_true) / n
    return self.gradient

## Linear layer
class Linear:
  def __init__(self, input_dim: int, num_hidden: int = 1):
    self.weights = torch.rand(input_dim, num_hidden) * math.sqrt(2. / input_dim)
    self.bias = torch.zeros(num_hidden)
  
  def __call__(self, x):
    self.x = x
    output = torch.matmul(x, self.weights) + self.bias
    return output

  def backward(self, gradient):
    self.weights_gradient = torch.matmul(self.x.T, gradient)
    self.bias_gradient = gradient.sum(axis=0)
    self.x_gradient = torch.matmul(gradient, self.weights.T)
    return self.x_gradient

  def update(self, lr):
    self.weights = self.weights - lr * self.weights_gradient
    self.bias = self.bias - lr * self.bias_gradient

## Adding non-linear activation function reLu
class Relu:
    def __call__(self, input_):
        self.input_ = input_
        self.output = torch.clip(self.input_, 0, None)
        return self.output
    
    def backward(self, output_gradient):
      self.input_gradient = (self.input_ > 0) * output_gradient
      return self.input_gradient

# %%
## Model class
class TorchModel(nn.Module):
  def __init__(self, input_dim, num_hidden):
    super().__init__()
    self.linear1 = Linear(input_dim, num_hidden)
    self.relu = Relu()
    self.linear2 = Linear(num_hidden, 2)
  
  def forward(self, x):
    l1 = self.linear1(x)
    r = self.relu(l1)
    l2 = self.linear2(r)
    return l2

  def backward(self, output_gradient):
    linear2_gradient = self.linear2.backward(output_gradient)
    relu_gradient = self.relu.backward(linear2_gradient)
    linear1_gradient = self.linear1.backward(relu_gradient)
    return linear1_gradient

  def update(self, lr):
    self.linear2.update(lr)
    self.linear1.update(lr)

# %%
##Calculating the loss 
loss = MSE()
model = TorchModel(d, 4)
x_tensor = torch.tensor(x).float()
y_true_tensor = torch.tensor(y_true).float()
y_pred_tensor = model(x_tensor)
loss_value = loss(y_pred_tensor, y_true_tensor)
print(loss_value)
# Out:
# tensor(3.7132)
# <ipython-input-8-134c137c1c80>:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_tensor = torch.tensor(x).float()
# <ipython-input-8-134c137c1c80>:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_true_tensor = torch.tensor(y_true).float()

# %%
def plot_3d(x, y, y_pred=None):
  import matplotlib.pyplot as plt
  from mpl_toolkits.mplot3d import Axes3D
  fig = plt.figure()
  ax = fig.add_subplot(111, projection='3d')
  ax.scatter(x[:, 0], x[:, 1], y[:, 0], label='underlying function')
  if y_pred is not None:
    ax.scatter(x[:, 0], x[:, 1], y_pred[:, 0], label='our function')
  plt.legend()

# %%
plot_3d(x, y_true, model(x_tensor).detach())

# %%
loss = MSE()
model = TorchModel(d, 10)
y_pred_tensor = model(x_tensor)
loss_value = loss(y_pred_tensor, y_true_tensor)
print(loss_value)
loss_gradient = loss.backward()
model.backward(loss_gradient)
model.update(0.01)
y_pred_tensor = model(x_tensor)
loss_value = loss(y_pred_tensor, y_true_tensor)
print(loss_value)
# Out:
# tensor(2.5349)
# tensor(2.4116)

# %%
from typing import Callable

def fit(x, y, model: Callable, loss: Callable, lr: float, num_epochs: int):
  for epoch in range(num_epochs):
    y_pred = model(x)
    loss_value = loss(y_pred, y)
    print(f'Epoch {epoch}, loss {loss_value}')
    gradient_from_loss = loss.backward()
    model.backward(gradient_from_loss)
    model.update(lr)

fit(x_tensor, y_true_tensor, model=model, loss=loss, lr=0.01, num_epochs=70)
# Out:
# Epoch 0, loss 2.4116013050079346
# Epoch 1, loss 2.313472032546997
# Epoch 2, loss 2.2354602813720703
# Epoch 3, loss 2.173283338546753
# Epoch 4, loss 2.1234054565429688
# Epoch 5, loss 2.0829689502716064
# Epoch 6, loss 2.04970645904541
# Epoch 7, loss 2.021850347518921
# Epoch 8, loss 1.9980382919311523
# Epoch 9, loss 1.9772366285324097
# Epoch 10, loss 1.9586659669876099
# Epoch 11, loss 1.9417436122894287
# Epoch 12, loss 1.926037311553955
# Epoch 13, loss 1.911226511001587
# Epoch 14, loss 1.8970751762390137
# Epoch 15, loss 1.8834092617034912
# Epoch 16, loss 1.870100975036621
# Epoch 17, loss 1.8570553064346313
# Epoch 18, loss 1.844203233718872
# Epoch 19, loss 1.8314930200576782
# Epoch 20, loss 1.8188862800598145
# Epoch 21, loss 1.8063552379608154
# Epoch 22, loss 1.7938783168792725
# Epoch 23, loss 1.7814393043518066
# Epoch 24, loss 1.769026517868042
# Epoch 25, loss 1.756630539894104
# Epoch 26, loss 1.7442442178726196
# Epoch 27, loss 1.7318626642227173
# Epoch 28, loss 1.7194812297821045
# Epoch 29, loss 1.7070965766906738
# Epoch 30, loss 1.6947060823440552
# Epoch 31, loss 1.6823077201843262
# Epoch 32, loss 1.6698999404907227
# Epoch 33, loss 1.6574815511703491
# Epoch 34, loss 1.6450510025024414
# Epoch 35, loss 1.6326079368591309
# Epoch 36, loss 1.620151162147522
# Epoch 37, loss 1.6076806783676147
# Epoch 38, loss 1.5951958894729614
# Epoch 39, loss 1.582696557044983
# Epoch 40, loss 1.570182204246521
# Epoch 41, loss 1.5576530694961548
# Epoch 42, loss 1.5451091527938843
# Epoch 43, loss 1.53255033493042
# Epoch 44, loss 1.5199769735336304
# Epoch 45, loss 1.5073891878128052
# Epoch 46, loss 1.494787335395813
# Epoch 47, loss 1.482171893119812
# Epoch 48, loss 1.4695430994033813
# Epoch 49, loss 1.4569015502929688
# Epoch 50, loss 1.444248080253601
# Epoch 51, loss 1.4315829277038574
# Epoch 52, loss 1.4189070463180542
# Epoch 53, loss 1.4062528610229492
# Epoch 54, loss 1.3936374187469482
# Epoch 55, loss 1.381014347076416
# Epoch 56, loss 1.368384838104248
# Epoch 57, loss 1.355749487876892
# Epoch 58, loss 1.3431094884872437
# Epoch 59, loss 1.3304660320281982
# Epoch 60, loss 1.3178198337554932
# Epoch 61, loss 1.3051725625991821
# Epoch 62, loss 1.2925255298614502
# Epoch 63, loss 1.2798794507980347
# Epoch 64, loss 1.267236351966858
# Epoch 65, loss 1.2545990943908691
# Epoch 66, loss 1.2419720888137817
# Epoch 67, loss 1.2293521165847778
# Epoch 68, loss 1.2167433500289917
# Epoch 69, loss 1.2041658163070679

# %%
def tsne_plot(view, y, y_pred=None):
  fig = plt.figure()
  tsne = fig.add_subplot(111, projection='3d')
  tsne.scatter(view[:, 0], view[:, 1], y[:, 0], label='underlying function')
  if y_pred is not None:
    tsne.scatter(view[:, 0], view[:, 1], y_pred[:, 0], label='our function')
  plt.legend()

# %%
tsne_plot(view, y_true, model(x_tensor).detach())
